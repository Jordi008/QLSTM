# %%
import helper
import pennylane
import pandas as pd
import time
import numpy as np
import math
import matplotlib.pyplot as plt
import torch

from torch import *
from torch import nn
from torch.utils.data import DataLoader
from IPython.display import Image

df = pd.read_csv('data_Luis.csv')
df
# Out:
#            Fecha     Apertura       Maximo       Minimo       Cierre  \
# 0     04/01/2010  32120.74023  32758.52930  32120.74023  32758.52930
# 1     05/01/2010  32729.30078  33073.71094  32628.24023  32732.75977
# 2     06/01/2010  32730.41992  32922.12109  32639.43945  32830.16016
# 3     07/01/2010  32830.21875  33069.78125  32670.98047  33064.57031
# 4     08/01/2010  33067.57031  33080.05078  32779.66016  32892.03906
# ...          ...          ...          ...          ...          ...
# 3266  26/12/2022  50530.62891  50712.39063  50211.37109  50273.89063
# 3267  27/12/2022  50305.69922  50838.64844  50277.12109  50440.01953
# 3268  28/12/2022  50432.78125  50491.08984  49605.37891  49648.21094
# 3269  29/12/2022  49708.67188  50209.78906  49461.51953  49517.85938
# 3270  30/12/2022  49524.32813  49619.33984  48383.19922  48463.85938
#
#        Aj_ Cierre    Volumen Variacion Yahoo = Investing
# 0     32758.52930  136257800     1.99%                si
# 1     32732.75977  165541900    -0.08%                si
# 2     32830.16016  126000100     0.30%                si
# 3     33064.57031  123563200     0.71%                si
# 4     32892.03906  109516900    -0.52%                si
# ...           ...        ...       ...               ...
# 3266  50273.89063   11411000    -0.60%                si
# 3267  50440.01953   54768700     0.33%                si
# 3268  49648.21094   73263800    -1.57%                si
# 3269  49517.85938   63993800    -0.26%                si
# 3270  48463.85938  119821400    -2.13%                si
#
# [3271 rows x 9 columns]

# %%
target = "Cierre"

# %%
df = df.drop(['Fecha' ,'Yahoo = Investing','Variacion'], axis=1)
df
# Out:
#          Apertura       Maximo       Minimo       Cierre   Aj_ Cierre  \
# 0     32120.74023  32758.52930  32120.74023  32758.52930  32758.52930
# 1     32729.30078  33073.71094  32628.24023  32732.75977  32732.75977
# 2     32730.41992  32922.12109  32639.43945  32830.16016  32830.16016
# 3     32830.21875  33069.78125  32670.98047  33064.57031  33064.57031
# 4     33067.57031  33080.05078  32779.66016  32892.03906  32892.03906
# ...           ...          ...          ...          ...          ...
# 3266  50530.62891  50712.39063  50211.37109  50273.89063  50273.89063
# 3267  50305.69922  50838.64844  50277.12109  50440.01953  50440.01953
# 3268  50432.78125  50491.08984  49605.37891  49648.21094  49648.21094
# 3269  49708.67188  50209.78906  49461.51953  49517.85938  49517.85938
# 3270  49524.32813  49619.33984  48383.19922  48463.85938  48463.85938
#
#         Volumen
# 0     136257800
# 1     165541900
# 2     126000100
# 3     123563200
# 4     109516900
# ...         ...
# 3266   11411000
# 3267   54768700
# 3268   73263800
# 3269   63993800
# 3270  119821400
#
# [3271 rows x 6 columns]

# %%
features = list(df.columns.difference(['Cierre','Yahoo = Investing','Variacion']))
features
# Out:
# ['Aj_ Cierre', 'Apertura', 'Maximo', 'Minimo', 'Volumen']

# %%
training_percentage = 0.67
size = int(len(df) * training_percentage)

df_train = df.loc[:size].copy()
df_test = df.loc[size:].copy()

# %%
target_mean = df_train[target].mean()
target_stdev = df_train[target].std()

for c in df_train.columns:
    mean = df_train[c].mean()
    stdev = df_train[c].std()

    df_train[c] = (df_train[c] - mean) / stdev
    df_test[c] = (df_test[c] - mean) / stdev

# %% [markdown]
# ## Classic prediction

# %%
from utils import SequenceDataset

# %%
torch.manual_seed(101) #Sets the seed for generating random numbers.

batch_size = 1
sequence_length = 3

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([1, 3, 5])
# Target shape: torch.Size([1])

# %%
import matplotlib.pyplot as plt
import numpy as np

def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()

    for X, y in data_loader:
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    accuracy = 1.0 / (avg_loss + 1e-7)

    print(f"Train loss: {avg_loss}")
    print(f"Train accuracy: {accuracy}")
    return avg_loss, accuracy


def test_model(data_loader, model, loss_function):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    accuracy = 1.0 / (avg_loss + 1e-7)
    print(f"Test loss: {avg_loss}")
    print(f"Test accuracy: {accuracy}")
    return avg_loss, accuracy

# %%
from utils import ShallowRegressionLSTM

# %%
learning_rate = 0.0001
num_hidden_units = 16

model = ShallowRegressionLSTM(num_sensors=len(features), hidden_units=num_hidden_units)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
classical_loss_train = []
classical_acc_train = []
classical_loss_test = []
classical_acc_test = []
print("Untrained test\n--------")
test_loss, test_accuracy = test_model(test_loader, model, loss_function)
print()
classical_loss_test.append(test_loss)
classical_acc_test.append(test_accuracy)

for ix_epoch in range(0,100):
  print(f"Epoch {ix_epoch}\n---------")
  train_loss, train_accuracy = train_model(train_loader, model, loss_function, optimizer=optimizer)
  test_loss, test_accuracy = test_model(test_loader, model, loss_function)
  classical_loss_train.append(train_loss)
  classical_acc_train.append(train_accuracy)
  classical_loss_test.append(test_loss)
  classical_acc_test.append(test_accuracy)
# Out:
# Untrained test
# --------
# Test loss: 1.1550659011417632
# Test accuracy: 0.8657513934368398
#
# Epoch 0.0
# ---------
# C:\TEMP\ipykernel_40220\3338192698.py:11: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   for ix_epoch in range(0,100):
# Train loss: 0.2860037911095412
# Train accuracy: 3.496455926248199
# Test loss: 0.15040958386102476
# Test accuracy: 6.648508090236915
# Epoch 1.0
# ---------
# Train loss: 0.03038746667138429
# Train accuracy: 32.90819600049422
# Test loss: 0.08650121573861236
# Test accuracy: 11.5605177963047
# Epoch 2.0
# ---------
# Train loss: 0.013256130753121046
# Train accuracy: 75.43622456666728
# Test loss: 0.047191330664886365
# Test accuracy: 21.19028785334258
# Epoch 3.0
# ---------
# Train loss: 0.006917871871224321
# Train accuracy: 144.55103585482246
# Test loss: 0.027919644148504282
# Test accuracy: 35.8169471282054
# Epoch 4.0
# ---------
# Train loss: 0.004505973426088651
# Train accuracy: 221.92270419082297
# Test loss: 0.018860721006667046
# Test accuracy: 53.01996130743797
# Epoch 5.0
# ---------
# Train loss: 0.0036470583146319684
# Train accuracy: 274.1860686409247
# Test loss: 0.01641129838165013
# Test accuracy: 60.93325972259119
# Epoch 6.0
# ---------
# Train loss: 0.003212110175824353
# Train accuracy: 311.31213253920066
# Test loss: 0.013670164400980726
# Test accuracy: 73.1514746655711
# Epoch 7.0
# ---------
# Train loss: 0.0029231726924480715
# Train accuracy: 342.08235262600766
# Test loss: 0.011510712146026123
# Test accuracy: 86.87484317474767
# Epoch 8.0
# ---------
# Train loss: 0.002625764985921138
# Train accuracy: 380.8268914668535
# Test loss: 0.011165735391869049
# Test accuracy: 89.55890579653352
# Epoch 9.0
# ---------
# Train loss: 0.002353494457887448
# Train accuracy: 424.88203379675934
# Test loss: 0.009858026180312621
# Test accuracy: 101.43915605351766
# Epoch 10.0
# ---------
# Train loss: 0.002066829727024401
# Train accuracy: 483.809384966185
# Test loss: 0.007868175979705315
# Test accuracy: 127.0926442564172
# Epoch 11.0
# ---------
# Train loss: 0.0018097012698299623
# Train accuracy: 552.5468550997059
# Test loss: 0.007011597978027993
# Test accuracy: 142.6188069043506
# Epoch 12.0
# ---------
# Train loss: 0.0015582758969444476
# Train accuracy: 641.6937030152537
# Test loss: 0.006181645179456306
# Test accuracy: 161.76661621758268
# Epoch 13.0
# ---------
# Train loss: 0.0013273283753905362
# Train accuracy: 753.3363144401632
# Test loss: 0.004464913500208671
# Test accuracy: 223.96348856577146
# Epoch 14.0
# ---------
# Train loss: 0.0011211615388899772
# Train accuracy: 891.85258328755
# Test loss: 0.003836733549580675
# Test accuracy: 260.6315825478771
# Epoch 15.0
# ---------
# Train loss: 0.0009118607077934926
# Train accuracy: 1096.5384708509212
# Test loss: 0.003145285951630423
# Test accuracy: 317.9260082476194
# Epoch 16.0
# ---------
# Train loss: 0.0007242407259227742
# Train accuracy: 1380.565753397408
# Test loss: 0.0023157786060524987
# Test accuracy: 431.8015622176921
# Epoch 17.0
# ---------
# Train loss: 0.0006028816565844318
# Train accuracy: 1658.4252424268834
# Test loss: 0.0019125920285345012
# Test accuracy: 522.8233218320029
# Epoch 18.0
# ---------
# Train loss: 0.00047612608794805466
# Train accuracy: 2099.8429638929756
# Test loss: 0.0016445426258105335
# Test accuracy: 608.0348303675805
# Epoch 19.0
# ---------
# Train loss: 0.00039615071653909754
# Train accuracy: 2523.6547424674027
# Test loss: 0.001357555648524924
# Test accuracy: 736.5637973712168
# Epoch 20.0
# ---------
# Train loss: 0.00032408035175654574
# Train accuracy: 3084.702680411008
# Test loss: 0.0014241944464655422
# Test accuracy: 702.1020144265464
# Epoch 21.0
# ---------
# Train loss: 0.00026953930660115067
# Train accuracy: 3708.658105545405
# Test loss: 0.0012164749982069166
# Test accuracy: 821.9797394109514
# Epoch 22.0
# ---------
# Train loss: 0.0002399555905338941
# Train accuracy: 4165.701776725784
# Test loss: 0.0011727700721894246
# Test accuracy: 852.6093586250998
# Epoch 23.0
# ---------
# Train loss: 0.0002044549647467235
# Train accuracy: 4888.661593905496
# Test loss: 0.001045815554815858
# Test accuracy: 956.1001319805958
# Epoch 24.0
# ---------
# Train loss: 0.0001825087952211594
# Train accuracy: 5476.187490251439
# Test loss: 0.0009355941045136373
# Test accuracy: 1068.7253400188818
# Epoch 25.0
# ---------
# Train loss: 0.00016790550296978693
# Train accuracy: 5952.18598393074
# Test loss: 0.0009156627565703486
# Test accuracy: 1091.9858804316643
# Epoch 26.0
# ---------
# Train loss: 0.0001580550127567285
# Train accuracy: 6322.910558252011
# Test loss: 0.0010365563601518336
# Test accuracy: 964.6398155060132
# Epoch 27.0
# ---------
# Train loss: 0.0001450064020021585
# Train accuracy: 6891.494697698622
# Test loss: 0.0007472094410423271
# Test accuracy: 1338.1337704033647
# Epoch 28.0
# ---------
# Train loss: 0.00014008699578677252
# Train accuracy: 7133.329267723389
# Test loss: 0.0009072947199495424
# Test accuracy: 1102.056225382937
# Epoch 29.0
# ---------
# Train loss: 0.00013268956314922407
# Train accuracy: 7530.712326210731
# Test loss: 0.0006892410619316726
# Test accuracy: 1450.6607182195103
# Epoch 30.0
# ---------
# Train loss: 0.00012245016738441372
# Train accuracy: 8159.923575324164
# Test loss: 0.0008855038288815073
# Test accuracy: 1129.1730764793235
# Epoch 31.0
# ---------
# Train loss: 0.00011717883917592757
# Train accuracy: 8526.687397544245
# Test loss: 0.0006642775597533076
# Test accuracy: 1505.1682365239933
# Epoch 32.0
# ---------
# Train loss: 0.00011228840766332132
# Train accuracy: 8897.714815888048
# Test loss: 0.0006246541378016098
# Test accuracy: 1600.629654921228
# Epoch 33.0
# ---------
# Train loss: 0.00010145260939313196
# Train accuracy: 9847.112801688681
# Test loss: 0.0006304446073781253
# Test accuracy: 1585.9306198146892
# Epoch 34.0
# ---------
# Train loss: 9.833666554278893e-05
# Train accuracy: 10158.816275276158
# Test loss: 0.0005819157974059481
# Test accuracy: 1718.1664216968215
# Epoch 35.0
# ---------
# Train loss: 9.200788524463846e-05
# Train accuracy: 10856.833780777844
# Test loss: 0.0005542280975627433
# Test accuracy: 1803.9857701544925
# Epoch 36.0
# ---------
# Train loss: 8.44893975131426e-05
# Train accuracy: 11821.812536785483
# Test loss: 0.0005813912664044596
# Test accuracy: 1719.7162842759608
# Epoch 37.0
# ---------
# Train loss: 8.109538701930175e-05
# Train accuracy: 12315.97060757011
# Test loss: 0.0005802460132089347
# Test accuracy: 1723.1099675702997
# Epoch 38.0
# ---------
# Train loss: 7.787824039534255e-05
# Train accuracy: 12824.090347898225
# Test loss: 0.0006267527096068475
# Test accuracy: 1595.2710815068262
# Epoch 39.0
# ---------
# Train loss: 7.505367536701695e-05
# Train accuracy: 13306.069132566665
# Test loss: 0.0005040286120998309
# Test accuracy: 1983.6207983409865
# Epoch 40.0
# ---------
# Train loss: 7.029884940638572e-05
# Train accuracy: 14204.777612591099
# Test loss: 0.0004514297563544898
# Test accuracy: 2214.6934635575017
# Epoch 41.0
# ---------
# Train loss: 6.354954342169788e-05
# Train accuracy: 15711.031788157397
# Test loss: 0.0004067543191045026
# Test accuracy: 2457.8822272331463
# Epoch 42.0
# ---------
# Train loss: 6.133351999091219e-05
# Train accuracy: 16277.758463912358
# Test loss: 0.00043352680786818695
# Test accuracy: 2306.1304832979285
# Epoch 43.0
# ---------
# Train loss: 5.759851329127996e-05
# Train accuracy: 17331.469096121946
# Test loss: 0.00038836818131581034
# Test accuracy: 2574.213405620052
# Epoch 44.0
# ---------
# Train loss: 5.321191779791339e-05
# Train accuracy: 18757.531923549366
# Test loss: 0.00039878548120314506
# Test accuracy: 2506.985205336963
# Epoch 45.0
# ---------
# Train loss: 5.032460988947204e-05
# Train accuracy: 19831.586247111176
# Test loss: 0.00048806868923080733
# Test accuracy: 2048.4722229434046
# Epoch 46.0
# ---------
# Train loss: 4.729310034759069e-05
# Train accuracy: 21100.117794906757
# Test loss: 0.0004374879905873432
# Test accuracy: 2285.254672226656
# Epoch 47.0
# ---------
# Train loss: 4.4458410401454716e-05
# Train accuracy: 22442.452300034307
# Test loss: 0.0003537389866357584
# Test accuracy: 2826.1442005241756
# Epoch 48.0
# ---------
# Train loss: 4.2628885435109204e-05
# Train accuracy: 23403.37197698881
# Test loss: 0.00035968712643096127
# Test accuracy: 2779.4212925844854
# Epoch 49.0
# ---------
# Train loss: 3.764611810446491e-05
# Train accuracy: 26492.79052305281
# Test loss: 0.00032326757617770957
# Test accuracy: 3092.455996424456
# Epoch 50.0
# ---------
# Train loss: 3.763647556496652e-05
# Train accuracy: 26499.560041806653
# Test loss: 0.00031845622690131984
# Test accuracy: 3139.163248281984
# Epoch 51.0
# ---------
# Train loss: 3.513155759383995e-05
# Train accuracy: 28383.644331831772
# Test loss: 0.00034284154200702084
# Test accuracy: 2915.948864484687
# Epoch 52.0
# ---------
# Train loss: 3.204318963384024e-05
# Train accuracy: 31110.789296006995
# Test loss: 0.00036027662984875516
# Test accuracy: 2774.8747204270308
# Epoch 53.0
# ---------
# Train loss: 3.115857105118721e-05
# Train accuracy: 31991.22565015715
# Test loss: 0.00029161442439935755
# Test accuracy: 3428.010123458956
# Epoch 54.0
# ---------
# Train loss: 2.6469167899170814e-05
# Train accuracy: 37637.61077482628
# Test loss: 0.0002963366638842966
# Test accuracy: 3373.4018825360754
# Epoch 55.0
# ---------
# Train loss: 2.9166209877635218e-05
# Train accuracy: 34169.098225601956
# Test loss: 0.0002545774055543151
# Test accuracy: 3926.5359949127087
# Epoch 56.0
# ---------
# Train loss: 2.3814069838881985e-05
# Train accuracy: 41816.38703647574
# Test loss: 0.0003021932763044174
# Test accuracy: 3308.045789920161
# Epoch 57.0
# ---------
# Train loss: 2.3470030330516575e-05
# Train accuracy: 42426.75915038092
# Test loss: 0.00022931881614631207
# Test accuracy: 4358.840381088224
# Epoch 58.0
# ---------
# Train loss: 2.244146183103729e-05
# Train accuracy: 44362.69517459166
# Test loss: 0.0002967714256900626
# Test accuracy: 3368.461608171115
# Epoch 59.0
# ---------
# Train loss: 1.982859902285193e-05
# Train accuracy: 50179.14198852161
# Test loss: 0.00025831526615925627
# Test accuracy: 3869.7404176722266
# Epoch 60.0
# ---------
# Train loss: 1.8591880984416612e-05
# Train accuracy: 53499.163665427695
# Test loss: 0.00024010278009244934
# Test accuracy: 4163.1491509595335
# Epoch 61.0
# ---------
# Train loss: 1.7086812540764268e-05
# Train accuracy: 58184.14540963695
# Test loss: 0.00023430298804371331
# Test accuracy: 4266.1572207156
# Epoch 62.0
# ---------
# Train loss: 1.8142441366887425e-05
# Train accuracy: 54817.224289679754
# Test loss: 0.00019989028444229452
# Test accuracy: 5000.242900742218
# Epoch 63.0
# ---------
# Train loss: 1.4511076847455812e-05
# Train accuracy: 68441.22513626552
# Test loss: 0.00022365299056259996
# Test accuracy: 4469.214009098248
# Epoch 64.0
# ---------
# Train loss: 1.6074285026276173e-05
# Train accuracy: 61826.53504469813
# Test loss: 0.00021466494155272735
# Test accuracy: 4656.2534497954275
# Epoch 65.0
# ---------
# Train loss: 1.5841973389890148e-05
# Train accuracy: 62727.49148070751
# Test loss: 0.0002046474672982798
# Test accuracy: 4884.065298562067
# Epoch 66.0
# ---------
# Train loss: 1.4881338331618139e-05
# Train accuracy: 66749.71073108324
# Test loss: 0.0002112368559423459
# Test accuracy: 4731.782327039097
# Epoch 67.0
# ---------
# Train loss: 1.3382668543431677e-05
# Train accuracy: 74169.29347322477
# Test loss: 0.00019759088836942532
# Test accuracy: 5058.402075321237
# Epoch 68.0
# ---------
# Train loss: 1.3009704295123592e-05
# Train accuracy: 76279.37118093269
# Test loss: 0.00020533743502223936
# Test accuracy: 4867.662020272724
# Epoch 69.0
# ---------
# Train loss: 1.1382159068924562e-05
# Train accuracy: 87091.63442147484
# Test loss: 0.00021529791643413434
# Test accuracy: 4642.570441510217
# Epoch 70.0
# ---------
# Train loss: 1.2309833894461099e-05
# Train accuracy: 80581.2558414929
# Test loss: 0.00018256879201281975
# Test accuracy: 5474.388859646149
# Epoch 71.0
# ---------
# Train loss: 1.2370106835095961e-05
# Train accuracy: 80191.77487602532
# Test loss: 0.00016849993484283375
# Test accuracy: 5931.200394188672
# Epoch 72.0
# ---------
# Train loss: 1.0018436709026422e-05
# Train accuracy: 98829.49597420747
# Test loss: 0.00018405122646221635
# Test accuracy: 5430.319521684953
# Epoch 73.0
# ---------
# Train loss: 1.0280806306873802e-05
# Train accuracy: 96331.6307460467
# Test loss: 0.00017112273953989862
# Test accuracy: 5840.3457548170945
# Epoch 74.0
# ---------
# Train loss: 1.0375508534978465e-05
# Train accuracy: 95460.75941429756
# Test loss: 0.00016947476457547116
# Test accuracy: 5897.103867450388
# Epoch 75.0
# ---------
# Train loss: 9.3757018173338e-06
# Train accuracy: 105533.08021688806
# Test loss: 0.00019577323915782668
# Test accuracy: 5105.342640472907
# Epoch 76.0
# ---------
# Train loss: 9.375786366117351e-06
# Train accuracy: 105532.13858595506
# Test loss: 0.0001500959594547092
# Test accuracy: 6657.968720533689
# Epoch 77.0
# ---------
# Train loss: 1.1278652684685796e-05
# Train accuracy: 87883.86707205427
# Test loss: 0.0001730593678418544
# Test accuracy: 5775.026857994163
# Epoch 78.0
# ---------
# Train loss: 8.740449971852013e-06
# Train accuracy: 113116.41411738082
# Test loss: 0.00019321007300506334
# Test accuracy: 5173.036171652613
# Epoch 79.0
# ---------
# Train loss: 8.389071166607714e-06
# Train accuracy: 117798.51769102392
# Test loss: 0.0002048797755170199
# Test accuracy: 4878.530076821983
# Epoch 80.0
# ---------
# Train loss: 9.350312059247893e-06
# Train accuracy: 105816.61152886684
# Test loss: 0.00015579356501337245
# Test accuracy: 6414.632957519579
# Epoch 81.0
# ---------
# Train loss: 9.679015341579715e-06
# Train accuracy: 102259.78435150493
# Test loss: 0.00019177864487924964
# Test accuracy: 5211.6273837002855
# Epoch 82.0
# ---------
# Train loss: 9.541571127557359e-06
# Train accuracy: 103717.53594617153
# Test loss: 0.0001610443946311544
# Test accuracy: 6205.614550161136
# Epoch 83.0
# ---------
# Train loss: 8.19368841340102e-06
# Train accuracy: 120573.61576113597
# Test loss: 0.0001750993463039266
# Test accuracy: 5707.783853629526
# Epoch 84.0
# ---------
# Train loss: 8.824793275751276e-06
# Train accuracy: 112047.41321202439
# Test loss: 0.00017458103437947847
# Test accuracy: 5724.719936267334
# Epoch 85.0
# ---------
# Train loss: 7.464946464125884e-06
# Train accuracy: 132188.6420138134
# Test loss: 0.0001748364747008679
# Test accuracy: 5716.360763013814
# Epoch 86.0
# ---------
# Train loss: 8.925099769529374e-06
# Train accuracy: 110802.09920517546
# Test loss: 0.00016444551498188064
# Test accuracy: 6077.34583413056
# Epoch 87.0
# ---------
# Train loss: 9.527842158204493e-06
# Train accuracy: 103865.43355904902
# Test loss: 0.00015821413839799922
# Test accuracy: 6316.555237069326
# Epoch 88.0
# ---------
# Train loss: 7.883489069408722e-06
# Train accuracy: 125258.51683467795
# Test loss: 0.00014187479743558204
# Test accuracy: 7043.503622209626
# Epoch 89.0
# ---------
# Train loss: 8.34776243526943e-06
# Train accuracy: 118374.54091097512
# Test loss: 0.00016333729779857285
# Test accuracy: 6118.554414870729
# Epoch 90.0
# ---------
# Train loss: 6.792548942181859e-06
# Train accuracy: 145084.2073648659
# Test loss: 0.00017480893167005093
# Test accuracy: 5717.260922309016
# Epoch 91.0
# ---------
# Train loss: 7.559579731042431e-06
# Train accuracy: 130555.46584980907
# Test loss: 0.000123049085219456
# Test accuracy: 8120.238962538494
# Epoch 92.0
# ---------
# Train loss: 9.177736400744818e-06
# Train accuracy: 107784.91183687001
# Test loss: 0.00015088714895578084
# Test accuracy: 6623.080221833098
# Epoch 93.0
# ---------
# Train loss: 8.018294126805683e-06
# Train accuracy: 123178.58707509915
# Test loss: 0.0001352752409056769
# Test accuracy: 7386.875128050578
# Epoch 94.0
# ---------
# Train loss: 8.270833230887675e-06
# Train accuracy: 119462.42057601667
# Test loss: 0.00014758193627437604
# Test accuracy: 6771.308835916906
# Epoch 95.0
# ---------
# Train loss: 8.496482161924154e-06
# Train accuracy: 116326.6532942086
# Test loss: 0.00014561896533352056
# Test accuracy: 6862.5247078251405
# Epoch 96.0
# ---------
# Train loss: 7.4227691332169345e-06
# Train accuracy: 132929.77390260197
# Test loss: 0.00013647635509238574
# Test accuracy: 7321.911609982268
# Epoch 97.0
# ---------
# Train loss: 7.213909108787923e-06
# Train accuracy: 136725.7898786935
# Test loss: 0.00014579180485271118
# Test accuracy: 6854.394604341043
# Epoch 98.0
# ---------
# Train loss: 6.476990290383873e-06
# Train accuracy: 152045.2297857405
# Test loss: 0.00013365967023508632
# Test accuracy: 7476.094986197801
# Epoch 99.0
# ---------
# Train loss: 8.46598972085086e-06
# Train accuracy: 116740.74246970609
# Test loss: 0.00013065390917835443
# Test accuracy: 7647.954896980964
# Epoch 100.0
# ---------
# Train loss: 7.354238260166329e-06
# Train accuracy: 134151.869728093
# Test loss: 0.0001283076658529822
# Test accuracy: 7787.697045633786

# %%
def predict(data_loader, model):
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            y_star = model(X)
            output = torch.cat((output, y_star), 0)

    return output

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)
# Out:
#            Cierre  Model forecast
# 0     32758.52930    32750.296875
# 1     32732.75977    32745.546875
# 2     32830.16016    32859.054688
# 3     33064.57031    33080.113281
# 4     32892.03906    32911.281250
# ...           ...             ...
# 3266  50273.89063    50271.687500
# 3267  50440.01953    50429.367188
# 3268  49648.21094    49654.277344
# 3269  49517.85938    49521.492188
# 3270  48463.85938    48451.656250
#
# [3272 rows x 2 columns]

# %%
plt.figure(figsize=(12, 7))
plt.plot(range(1,3272), df_out["Cierre"], label = "Real")
plt.plot(range(1,3272), df_out["Model forecast"], label = "LSTM Prediction")
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.vlines(size, ymin = 0, ymax = 60000, label = "Test set start", linestyles = "dashed")
plt.legend()
plt.show()
# Out:
# C:\TEMP\ipykernel_40220\3916468802.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1,3272), df_out["Cierre"], label = "Real")
# C:\TEMP\ipykernel_40220\3916468802.py:3: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1,3272), df_out["Model forecast"], label = "LSTM Prediction")

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 102), classical_loss_test)
plt.ylabel('Test Loss')
plt.xlabel('Epoch')
plt.show()
# Out:
# C:\TEMP\ipykernel_40220\2267726858.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 102), classical_loss_test)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 102), classical_acc_test)
plt.ylabel('Test Accuracy')
plt.xlabel('Epoch')
plt.show()
# Out:
# C:\TEMP\ipykernel_40220\1535722248.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 102), classical_acc_test)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 101), classical_loss_train)
plt.ylabel('Train Loss')
plt.xlabel('Epoch')
plt.show()
# Out:
# C:\TEMP\ipykernel_40220\1213986256.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 101), classical_loss_train)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 101), classical_acc_train)
plt.ylabel('Train Accuracy')
plt.xlabel('Epoch')
plt.show()
# Out:
# C:\TEMP\ipykernel_40220\1783397884.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 101), classical_acc_train)

# %%
torch.save(model.state_dict(), "./Cmodel_final_IPindex" )

# %% [markdown]
# ## Quantum prediction

# %%
from utils import QShallowRegressionLSTM

# %%
learning_rate = 0.05
num_hidden_units = 16

Qmodel = QShallowRegressionLSTM(num_sensors=len(features), hidden_units=num_hidden_units, n_qubits=4)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adagrad(Qmodel.parameters(), lr=learning_rate)
# Out:
# weight_shapes = (n_qlayers, n_vrotations, n_qubits) = (1, 3, 4)

# %%
quantum_loss_train = []
quantum_acc_train = []
quantum_loss_test = []
quantum_acc_test = []
print("Untrained test\n--------")
start = time.time()
test_loss, test_accuracy = test_model(test_loader, Qmodel, loss_function)
end = time.time()
print("Execution time", end - start)
quantum_loss_test.append(test_loss)

for ix_epoch in range(0, 100):
    print(f"Epoch {ix_epoch}\n---------")
    start = time.time()
    train_loss, train_accuracy = train_model(train_loader, Qmodel, loss_function, optimizer=optimizer)
    test_loss, test_accuracy = test_model(test_loader, Qmodel, loss_function)
    end = time.time()
    print("Execution time", end - start)
    quantum_loss_train.append(train_loss)
    quantum_acc_train.append(train_accuracy)
    quantum_loss_test.append(test_loss)
    quantum_acc_test.append(test_accuracy)
# Out:
# Untrained test
# --------
# Test loss: 1.3969012679048556
# Test accuracy: 0.7158701558864183
# Execution time 153.59780502319336
# Epoch 0.0
# ---------
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\3932626814.py:12: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   for ix_epoch in range(0, 100):
# Train loss: 0.017681026203977948
# Train accuracy: 56.55748329962247
# Test loss: 0.011849078255966839
# Test accuracy: 84.3940379997604
# Execution time 627.8859283924103
# Epoch 1.0
# ---------
# Train loss: 0.0013538395290853783
# Train accuracy: 738.5854231433262
# Test loss: 0.00948329932352641
# Test accuracy: 105.4474208967665
# Execution time 597.7659993171692
# Epoch 2.0
# ---------
# Train loss: 0.0009307776784679168
# Train accuracy: 1074.2549994816163
# Test loss: 0.0051500959620172995
# Test accuracy: 194.16736904284826
# Execution time 591.4961569309235
# Epoch 3.0
# ---------
# Train loss: 0.000716552607792624
# Train accuracy: 1395.3762103512329
# Test loss: 0.005281566791516512
# Test accuracy: 189.3341703430088
# Execution time 587.445131778717
# Epoch 4.0
# ---------
# Train loss: 0.0005730266425699429
# Train accuracy: 1744.8150648099781
# Test loss: 0.004355062668495001
# Test accuracy: 229.61254862738951
# Execution time 586.8371093273163
# Epoch 5.0
# ---------
# Train loss: 0.000492788006957197
# Train accuracy: 2028.858454425411
# Test loss: 0.0038552000394364364
# Test accuracy: 259.3831841285637
# Execution time 588.032986164093
# Epoch 6.0
# ---------
# Train loss: 0.00039720873765977487
# Train accuracy: 2516.934326413743
# Test loss: 0.0037978998161304774
# Test accuracy: 263.2964845740387
# Execution time 587.2587518692017
# Epoch 7.0
# ---------
# Train loss: 0.0003505460242503647
# Train accuracy: 2851.8789059076576
# Test loss: 0.0027629188217926184
# Test accuracy: 361.9229779083482
# Execution time 585.935870885849
# Epoch 8.0
# ---------
# Train loss: 0.00031938352685853197
# Train accuracy: 3130.0518365781104
# Test loss: 0.002688859618154996
# Test accuracy: 371.89104412290897
# Execution time 586.8823492527008
# Epoch 9.0
# ---------
# Train loss: 0.0002824027959793945
# Train accuracy: 3539.7879746044678
# Test loss: 0.0025463726861436114
# Test accuracy: 392.7000691746685
# Execution time 587.1487188339233
# Epoch 10.0
# ---------
# Train loss: 0.00025689199482869477
# Train accuracy: 3891.17178792506
# Test loss: 0.0021880060652042085
# Test accuracy: 457.01623696503646
# Execution time 585.1044704914093
# Epoch 11.0
# ---------
# Train loss: 0.00024191319759903125
# Train accuracy: 4132.006063804856
# Test loss: 0.0019953566961167604
# Test accuracy: 501.1384120467463
# Execution time 586.8543577194214
# Epoch 12.0
# ---------
# Train loss: 0.00021543986508715374
# Train accuracy: 4639.512971744921
# Test loss: 0.0018544716035856722
# Test accuracy: 539.2080834552715
# Execution time 585.5704092979431
# Epoch 13.0
# ---------
# Train loss: 0.0002254670509532756
# Train accuracy: 4433.271596068089
# Test loss: 0.001746461860383738
# Test accuracy: 572.5534392353497
# Execution time 585.9985730648041
# Epoch 14.0
# ---------
# Train loss: 0.00018635241192913225
# Train accuracy: 5363.298815249893
# Test loss: 0.001536125188128887
# Test accuracy: 650.9462334867676
# Execution time 587.5395843982697
# Epoch 15.0
# ---------
# Train loss: 0.00017994102731486478
# Train accuracy: 5554.289568961133
# Test loss: 0.0016117472082306623
# Test accuracy: 620.4061991072392
# Execution time 587.0540640354156
# Epoch 16.0
# ---------
# Train loss: 0.00016398163894723594
# Train accuracy: 6094.527129397897
# Test loss: 0.0015045529212798965
# Test accuracy: 664.6050965357341
# Execution time 587.1981127262115
# Epoch 17.0
# ---------
# Train loss: 0.00015857632532431174
# Train accuracy: 6302.137372769018
# Test loss: 0.0013080765774602812
# Test accuracy: 764.422798290288
# Execution time 587.127521276474
# Epoch 18.0
# ---------
# Train loss: 0.0001455902618157165
# Train accuracy: 6863.87674465778
# Test loss: 0.0012810924190871183
# Test accuracy: 780.5228825132489
# Execution time 587.5474214553833
# Epoch 19.0
# ---------
# Train loss: 0.00013466309926346654
# Train accuracy: 7420.428926504319
# Test loss: 0.001285794664871201
# Test accuracy: 777.668674828947
# Execution time 587.3341701030731
# Epoch 20.0
# ---------
# Train loss: 0.00013015849530726423
# Train accuracy: 7677.042465761019
# Test loss: 0.0012825540813152891
# Test accuracy: 779.6334292832535
# Execution time 587.5975341796875
# Epoch 21.0
# ---------
# Train loss: 0.00012019910735427862
# Train accuracy: 8312.613634405605
# Test loss: 0.0011322166136918746
# Test accuracy: 883.1452156650238
# Execution time 587.5636615753174
# Epoch 22.0
# ---------
# Train loss: 0.00011652982641764433
# Train accuracy: 8574.136056921328
# Test loss: 0.0011022348179363282
# Test accuracy: 907.1653945142472
# Execution time 588.2188911437988
# Epoch 23.0
# ---------
# Train loss: 0.00010979924080833033
# Train accuracy: 9099.243931484923
# Test loss: 0.0011027310655442803
# Test accuracy: 906.7571917793863
# Execution time 587.5314536094666
# Epoch 24.0
# ---------
# Train loss: 0.0001050748421676807
# Train accuracy: 9507.977187222166
# Test loss: 0.0009469892887913909
# Test accuracy: 1055.8666556942378
# Execution time 587.7442767620087
# Epoch 25.0
# ---------
# Train loss: 9.643971184640164e-05
# Train accuracy: 10358.431580892204
# Test loss: 0.0009560829179538124
# Test accuracy: 1045.8249998232077
# Execution time 588.1160123348236
# Epoch 26.0
# ---------
# Train loss: 9.458569767589459e-05
# Train accuracy: 10561.257133289133
# Test loss: 0.0008812949545140902
# Test accuracy: 1134.5651513869811
# Execution time 587.7116255760193
# Epoch 27.0
# ---------
# Train loss: 8.772102202042862e-05
# Train accuracy: 11386.795291079436
# Test loss: 0.0008288993769590731
# Test accuracy: 1206.2735241951443
# Execution time 586.387793302536
# Epoch 28.0
# ---------
# Train loss: 8.382056625747176e-05
# Train accuracy: 11916.03017706004
# Test loss: 0.0009761399351233439
# Test accuracy: 1024.3383455458152
# Execution time 587.9896309375763
# Epoch 29.0
# ---------
# Train loss: 7.873416182966204e-05
# Train accuracy: 12684.856118096524
# Test loss: 0.0007855171091342281
# Test accuracy: 1272.8847021954853
# Execution time 587.4471445083618
# Epoch 30.0
# ---------
# Train loss: 7.818006055997735e-05
# Train accuracy: 12774.645201427898
# Test loss: 0.00075985406438484
# Test accuracy: 1315.8690069109243
# Execution time 589.0557408332825
# Epoch 31.0
# ---------
# Train loss: 7.178447435722572e-05
# Train accuracy: 13911.209742322913
# Test loss: 0.0007771400013952043
# Test accuracy: 1286.6038780877525
# Execution time 587.6570990085602
# Epoch 32.0
# ---------
# Train loss: 7.136239164076584e-05
# Train accuracy: 13993.374375530253
# Test loss: 0.0006679619165540372
# Test accuracy: 1496.867244219142
# Execution time 587.1841323375702
# Epoch 33.0
# ---------
# Train loss: 6.721062567329375e-05
# Train accuracy: 14856.495389802345
# Test loss: 0.0006218545282495197
# Test accuracy: 1607.8345836865
# Execution time 586.9616801738739
# Epoch 34.0
# ---------
# Train loss: 6.379986353262409e-05
# Train accuracy: 15649.48569083328
# Test loss: 0.0008464077500677252
# Test accuracy: 1181.3240929217654
# Execution time 586.9828481674194
# Epoch 35.0
# ---------
# Train loss: 6.182156057556126e-05
# Train accuracy: 16149.463784584792
# Test loss: 0.0006625309869642223
# Test accuracy: 1509.1355817532776
# Execution time 586.6407387256622
# Epoch 36.0
# ---------
# Train loss: 6.059485718008349e-05
# Train accuracy: 16475.860500552288
# Test loss: 0.0005906962007367906
# Test accuracy: 1692.631060851247
# Execution time 587.4963567256927
# Epoch 37.0
# ---------
# Train loss: 5.7453700572516354e-05
# Train accuracy: 17375.077363444645
# Test loss: 0.0005534737785568924
# Test accuracy: 1806.4439443047556
# Execution time 587.7876145839691
# Epoch 38.0
# ---------
# Train loss: 5.3367995536312376e-05
# Train accuracy: 18702.77705325343
# Test loss: 0.0005627788617095642
# Test accuracy: 1776.5811936209873
# Execution time 587.8456447124481
# Epoch 39.0
# ---------
# Train loss: 5.216131902414457e-05
# Train accuracy: 19134.61081106665
# Test loss: 0.0005325241747870703
# Test accuracy: 1877.4964549811787
# Execution time 587.1991333961487
# Epoch 40.0
# ---------
# Train loss: 5.09617158490492e-05
# Train accuracy: 19584.14407687047
# Test loss: 0.0005018756323167407
# Test accuracy: 1992.1285728248497
# Execution time 587.8206813335419
# Epoch 41.0
# ---------
# Train loss: 4.67445985140045e-05
# Train accuracy: 21347.17836680879
# Test loss: 0.0005615625540404187
# Test accuracy: 1780.4284668905264
# Execution time 586.7779221534729
# Epoch 42.0
# ---------
# Train loss: 4.646422403843259e-05
# Train accuracy: 21475.71490023398
# Test loss: 0.00047940502989643415
# Test accuracy: 2085.483858669814
# Execution time 587.2675819396973
# Epoch 43.0
# ---------
# Train loss: 4.425666282049884e-05
# Train accuracy: 22544.527392576143
# Test loss: 0.0004703873320774942
# Test accuracy: 2125.4557388067774
# Execution time 587.7972614765167
# Epoch 44.0
# ---------
# Train loss: 4.334506482346063e-05
# Train accuracy: 23017.574126394054
# Test loss: 0.0005784776547866663
# Test accuracy: 1728.3764620476418
# Execution time 587.5569045543671
# Epoch 45.0
# ---------
# Train loss: 4.0874122219703496e-05
# Train accuracy: 24405.647902302673
# Test loss: 0.00044839918531876873
# Test accuracy: 2229.658453647479
# Execution time 587.3279366493225
# Epoch 46.0
# ---------
# Train loss: 4.0241026297319224e-05
# Train accuracy: 24788.660373433602
# Test loss: 0.0004420480896534384
# Test accuracy: 2261.6856736479704
# Execution time 587.8205876350403
# Epoch 47.0
# ---------
# Train loss: 3.7724108238227185e-05
# Train accuracy: 26438.16461452866
# Test loss: 0.000424842680129721
# Test accuracy: 2353.2585611187205
# Execution time 589.7042942047119
# Epoch 48.0
# ---------
# Train loss: 3.742846390110922e-05
# Train accuracy: 26646.441022342064
# Test loss: 0.0004615994733150873
# Test accuracy: 2165.911069423181
# Execution time 589.331307888031
# Epoch 49.0
# ---------
# Train loss: 3.741110223442945e-05
# Train accuracy: 26658.774081081334
# Test loss: 0.000387917455764487
# Test accuracy: 2577.203641598446
# Execution time 596.8165521621704
# Epoch 50.0
# ---------
# Train loss: 3.466346838812261e-05
# Train accuracy: 28765.829371089534
# Test loss: 0.00038952905969681905
# Test accuracy: 2566.543678179772
# Execution time 591.6692883968353
# Epoch 51.0
# ---------
# Train loss: 3.322355330778891e-05
# Train accuracy: 30008.804606268204
# Test loss: 0.0003524138510635447
# Test accuracy: 2836.7679652387287
# Execution time 587.1991746425629
# Epoch 52.0
# ---------
# Train loss: 3.489093710731112e-05
# Train accuracy: 28578.828767379786
# Test loss: 0.00037097841441928036
# Test accuracy: 2694.848207662392
# Execution time 587.0049779415131
# Epoch 53.0
# ---------
# Train loss: 3.1934682161299354e-05
# Train accuracy: 31216.16737025366
# Test loss: 0.0003680243721434584
# Test accuracy: 2716.4732239198197
# Execution time 587.0394234657288
# Epoch 54.0
# ---------
# Train loss: 3.0365049805470964e-05
# Train accuracy: 32824.49910258865
# Test loss: 0.00035631273871610084
# Test accuracy: 2805.735854454254
# Execution time 587.9647121429443
# Epoch 55.0
# ---------
# Train loss: 3.0332638606324458e-05
# Train accuracy: 32859.4576676694
# Test loss: 0.0003599462629895446
# Test accuracy: 2777.420856133255
# Execution time 589.5772960186005
# Epoch 56.0
# ---------
# Train loss: 2.9433651537942275e-05
# Train accuracy: 33859.68032822784
# Test loss: 0.00033384439714936035
# Test accuracy: 2994.510488980412
# Execution time 586.3620307445526
# Epoch 57.0
# ---------
# Train loss: 2.792034019129597e-05
# Train accuracy: 35688.36042578214
# Test loss: 0.0003079204116728456
# Test accuracy: 3246.53809326805
# Execution time 588.0013556480408
# Epoch 58.0
# ---------
# Train loss: 2.582294084299674e-05
# Train accuracy: 38575.870155185614
# Test loss: 0.00029523575285419926
# Test accuracy: 3385.9767750289207
# Execution time 588.9965028762817
# Epoch 59.0
# ---------
# Train loss: 2.6546854775158057e-05
# Train accuracy: 37527.88118664817
# Test loss: 0.00030801301934329074
# Test accuracy: 3245.562300909552
# Execution time 589.643018245697
# Epoch 60.0
# ---------
# Train loss: 2.5960888646459873e-05
# Train accuracy: 38371.67694340464
# Test loss: 0.00028721091557463063
# Test accuracy: 3480.549974928622
# Execution time 589.6705853939056
# Epoch 61.0
# ---------
# Train loss: 2.595158969466701e-05
# Train accuracy: 38385.37347318612
# Test loss: 0.0002895678602320184
# Test accuracy: 3452.2297337337295
# Execution time 589.835263967514
# Epoch 62.0
# ---------
# Train loss: 2.4390645530913397e-05
# Train accuracy: 40831.91677155862
# Test loss: 0.0002966227231823215
# Test accuracy: 3370.149711741319
# Execution time 589.1712801456451
# Epoch 63.0
# ---------
# Train loss: 2.3719343588509536e-05
# Train accuracy: 41982.68505108598
# Test loss: 0.0002683073287104047
# Test accuracy: 3725.6806839240203
# Execution time 588.6162724494934
# Epoch 64.0
# ---------
# Train loss: 2.2711809159825064e-05
# Train accuracy: 43836.94397028125
# Test loss: 0.0002500266487506395
# Test accuracy: 3997.9746460239703
# Execution time 588.414612531662
# Epoch 65.0
# ---------
# Train loss: 2.21619404956132e-05
# Train accuracy: 44919.713993353536
# Test loss: 0.0002564940433285931
# Test accuracy: 3897.2066031922836
# Execution time 588.4400644302368
# Epoch 66.0
# ---------
# Train loss: 2.2061131356434662e-05
# Train accuracy: 45124.05002778173
# Test loss: 0.00026458715899125234
# Test accuracy: 3778.04500910091
# Execution time 589.8912889957428
# Epoch 67.0
# ---------
# Train loss: 2.1168264253562806e-05
# Train accuracy: 47018.41147344605
# Test loss: 0.00025489540349858317
# Test accuracy: 3921.6393169438297
# Execution time 589.9153609275818
# Epoch 68.0
# ---------
# Train loss: 2.100666064184597e-05
# Train accuracy: 47378.40897566736
# Test loss: 0.000233913657970989
# Test accuracy: 4273.254854740023
# Execution time 589.5536332130432
# Epoch 69.0
# ---------
# Train loss: 2.101783184894199e-05
# Train accuracy: 47353.346079896
# Test loss: 0.00023862500032941728
# Test accuracy: 4188.92030001088
# Execution time 589.276154756546
# Epoch 70.0
# ---------
# Train loss: 1.924675491024171e-05
# Train accuracy: 51688.254936781355
# Test loss: 0.00025136136671132853
# Test accuracy: 3976.7540162460637
# Execution time 589.993586063385
# Epoch 71.0
# ---------
# Train loss: 1.8719059846487275e-05
# Train accuracy: 53137.617296363394
# Test loss: 0.00024106862246439534
# Test accuracy: 4146.476393908308
# Execution time 589.6018447875977
# Epoch 72.0
# ---------
# Train loss: 1.9612436724101003e-05
# Train accuracy: 50729.39555855978
# Test loss: 0.00022642970557105194
# Test accuracy: 4414.432082887894
# Execution time 589.912230014801
# Epoch 73.0
# ---------
# Train loss: 1.7824368485895894e-05
# Train accuracy: 55789.971110383485
# Test loss: 0.0002092877155090837
# Test accuracy: 4775.829363096604
# Execution time 590.613804101944
# Epoch 74.0
# ---------
# Train loss: 1.7984515023776582e-05
# Train accuracy: 55295.92575113305
# Test loss: 0.00021691849544481676
# Test accuracy: 4607.902188015486
# Execution time 590.4301295280457
# Epoch 75.0
# ---------
# Train loss: 1.7643174912120066e-05
# Train accuracy: 56359.699149272135
# Test loss: 0.00023160627674014263
# Test accuracy: 4315.8088510545385
# Execution time 588.8049252033234
# Epoch 76.0
# ---------
# Train loss: 1.7344253137853793e-05
# Train accuracy: 57325.46943096197
# Test loss: 0.00021225679617924533
# Test accuracy: 4709.055787204115
# Execution time 589.5026195049286
# Epoch 77.0
# ---------
# Train loss: 1.695187120345614e-05
# Train accuracy: 58644.590266276246
# Test loss: 0.00020128739529864627
# Test accuracy: 4965.554068153351
# Execution time 589.5867443084717
# Epoch 78.0
# ---------
# Train loss: 1.6262132629426763e-05
# Train accuracy: 61116.72742473268
# Test loss: 0.00021573422376100924
# Test accuracy: 4633.185518841945
# Execution time 590.5476181507111
# Epoch 79.0
# ---------
# Train loss: 1.5798114449588235e-05
# Train accuracy: 62900.541015157956
# Test loss: 0.00021430308149146245
# Test accuracy: 4664.112068929476
# Execution time 590.0514097213745
# Epoch 80.0
# ---------
# Train loss: 1.5473477843940393e-05
# Train accuracy: 64211.73292316963
# Test loss: 0.00019261683180198463
# Test accuracy: 5188.960355198729
# Execution time 589.6137008666992
# Epoch 81.0
# ---------
# Train loss: 1.4905015528205009e-05
# Train accuracy: 66644.38288119693
# Test loss: 0.00018722302771257784
# Test accuracy: 5338.371967457019
# Execution time 589.4173541069031
# Epoch 82.0
# ---------
# Train loss: 1.485419818000786e-05
# Train accuracy: 66870.85378719211
# Test loss: 0.00018952726614741258
# Test accuracy: 5273.503227234311
# Execution time 589.6413779258728
# Epoch 83.0
# ---------
# Train loss: 1.4547956416023151e-05
# Train accuracy: 68268.90875413289
# Test loss: 0.0001916425464616022
# Test accuracy: 5215.326584808119
# Execution time 591.2850124835968
# Epoch 84.0
# ---------
# Train loss: 1.4236271514762461e-05
# Train accuracy: 69753.14320534958
# Test loss: 0.00018611626662857236
# Test accuracy: 5370.1001427260035
# Execution time 590.1054790019989
# Epoch 85.0
# ---------
# Train loss: 1.4265069570988429e-05
# Train accuracy: 69613.30713076332
# Test loss: 0.00018080416279341028
# Test accuracy: 5527.788772566745
# Execution time 594.1058206558228
# Epoch 86.0
# ---------
# Train loss: 1.4431230233223726e-05
# Train accuracy: 68817.29791285207
# Test loss: 0.0001670521536649263
# Test accuracy: 5982.573230881625
# Execution time 592.9922075271606
# Epoch 87.0
# ---------
# Train loss: 1.433655184612864e-05
# Train accuracy: 69268.61834172429
# Test loss: 0.00016952447725849642
# Test accuracy: 5895.375574104594
# Execution time 589.6996610164642
# Epoch 88.0
# ---------
# Train loss: 1.3713214420288178e-05
# Train accuracy: 72394.44560646568
# Test loss: 0.000163695023021898
# Test accuracy: 6105.191608088779
# Execution time 589.8791360855103
# Epoch 89.0
# ---------
# Train loss: 1.4130865435777606e-05
# Train accuracy: 70269.79522172382
# Test loss: 0.00017911542903791287
# Test accuracy: 5579.8767180277255
# Execution time 589.6135325431824
# Epoch 90.0
# ---------
# Train loss: 1.3164090119157985e-05
# Train accuracy: 75391.52637056123
# Test loss: 0.00017790393921696782
# Test accuracy: 5617.853202569335
# Execution time 589.7683439254761
# Epoch 91.0
# ---------
# Train loss: 1.2875842637082006e-05
# Train accuracy: 77066.28601846847
# Test loss: 0.00016640688566689252
# Test accuracy: 6005.757635756654
# Execution time 589.6878235340118
# Epoch 92.0
# ---------
# Train loss: 1.2978797809676104e-05
# Train accuracy: 76459.62683666297
# Test loss: 0.0001616765927700713
# Test accuracy: 6181.363959255051
# Execution time 590.3556113243103
# Epoch 93.0
# ---------
# Train loss: 1.2281092287558942e-05
# Train accuracy: 80768.31807520273
# Test loss: 0.0001578470364348733
# Test accuracy: 6331.236233180814
# Execution time 591.2675402164459
# Epoch 94.0
# ---------
# Train loss: 1.1728337368527092e-05
# Train accuracy: 84542.73570694777
# Test loss: 0.000156140857494442
# Test accuracy: 6400.374498940351
# Execution time 588.4049117565155
# Epoch 95.0
# ---------
# Train loss: 1.2243610452443507e-05
# Train accuracy: 81013.57409590342
# Test loss: 0.00015977255560317786
# Test accuracy: 6254.98226526206
# Execution time 588.4553496837616
# Epoch 96.0
# ---------
# Train loss: 1.1840399424559132e-05
# Train accuracy: 83749.29216716067
# Test loss: 0.0001581615032926493
# Test accuracy: 6318.65601675001
# Execution time 591.3623087406158
# Epoch 97.0
# ---------
# Train loss: 1.1898636013581177e-05
# Train accuracy: 83342.8065380187
# Test loss: 0.0001615876863646631
# Test accuracy: 6184.7628751681505
# Execution time 592.2320261001587
# Epoch 98.0
# ---------
# Train loss: 1.1297188957361451e-05
# Train accuracy: 87740.93364084302
# Test loss: 0.00014929227824821942
# Test accuracy: 6693.786397302759
# Execution time 590.7420077323914
# Epoch 99.0
# ---------
# Train loss: 1.1628295380161651e-05
# Train accuracy: 85263.88256655734
# Test loss: 0.0001632591871750164
# Test accuracy: 6121.48001770259
# Execution time 590.8591930866241
# Epoch 100.0
# ---------
# Train loss: 1.1035342845811311e-05
# Train accuracy: 89804.1500694486
# Test loss: 0.00015512075221429554
# Test accuracy: 6442.437533219878
# Execution time 590.0929532051086

# %%
torch.save(Qmodel.state_dict(), "./model_saved_14112023" )

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col_Q = "Model forecast"
df_train[ystar_col_Q] = predict(train_eval_loader, Qmodel).numpy()
df_test[ystar_col_Q] = predict(test_loader, Qmodel).numpy()

df_out_Q = pd.concat((df_train, df_test))[[target, ystar_col_Q]]

for c in df_out_Q.columns:
    df_out_Q[c] = df_out_Q[c] * target_stdev + target_mean

print(df_out_Q)
# Out:
#            Cierre  Model forecast
# 0     32758.52930    32688.917969
# 1     32732.75977    32738.132812
# 2     32830.16016    32823.960938
# 3     33064.57031    33042.722656
# 4     32892.03906    32892.558594
# ...           ...             ...
# 3266  50273.89063    50284.035156
# 3267  50440.01953    50420.921875
# 3268  49648.21094    49678.089844
# 3269  49517.85938    49520.855469
# 3270  48463.85938    48489.468750
#
# [3272 rows x 2 columns]

# %%
plt.figure(figsize=(12, 7))
plt.plot(range(1,3272), df_out_Q["Cierre"], label = "Real")
plt.plot(range(1,3272), df_out_Q["Model forecast"], label = "QLSTM Prediction")
plt.ylabel('Index')
plt.xlabel('Days')
plt.vlines(size, ymin = 0, ymax = 60000, label = "Test set start", linestyles = "dashed")
plt.legend()
plt.show()
# Out:
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\1383697629.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1,3272), df_out_Q["Cierre"], label = "Real")
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\1383697629.py:3: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1,3272), df_out_Q["Model forecast"], label = "QLSTM Prediction")

# %%
quantum_loss_test
# Out:
# [1.3969012679048556,
#  0.011849078255966839,
#  0.00948329932352641,
#  0.0051500959620172995,
#  0.005281566791516512,
#  0.004355062668495001,
#  0.0038552000394364364,
#  0.0037978998161304774,
#  0.0027629188217926184,
#  0.002688859618154996,
#  0.0025463726861436114,
#  0.0021880060652042085,
#  0.0019953566961167604,
#  0.0018544716035856722,
#  0.001746461860383738,
#  0.001536125188128887,
#  0.0016117472082306623,
#  0.0015045529212798965,
#  0.0013080765774602812,
#  0.0012810924190871183,
#  0.001285794664871201,
#  0.0012825540813152891,
#  0.0011322166136918746,
#  0.0011022348179363282,
#  0.0011027310655442803,
#  0.0009469892887913909,
#  0.0009560829179538124,
#  0.0008812949545140902,
#  0.0008288993769590731,
#  0.0009761399351233439,
#  0.0007855171091342281,
#  0.00075985406438484,
#  0.0007771400013952043,
#  0.0006679619165540372,
#  0.0006218545282495197,
#  0.0008464077500677252,
#  0.0006625309869642223,
#  0.0005906962007367906,
#  0.0005534737785568924,
#  0.0005627788617095642,
#  0.0005325241747870703,
#  0.0005018756323167407,
#  0.0005615625540404187,
#  0.00047940502989643415,
#  0.0004703873320774942,
#  0.0005784776547866663,
#  0.00044839918531876873,
#  0.0004420480896534384,
#  0.000424842680129721,
#  0.0004615994733150873,
#  0.000387917455764487,
#  0.00038952905969681905,
#  0.0003524138510635447,
#  0.00037097841441928036,
#  0.0003680243721434584,
#  0.00035631273871610084,
#  0.0003599462629895446,
#  0.00033384439714936035,
#  0.0003079204116728456,
#  0.00029523575285419926,
#  0.00030801301934329074,
#  0.00028721091557463063,
#  0.0002895678602320184,
#  0.0002966227231823215,
#  0.0002683073287104047,
#  0.0002500266487506395,
#  0.0002564940433285931,
#  0.00026458715899125234,
#  0.00025489540349858317,
#  0.000233913657970989,
#  0.00023862500032941728,
#  0.00025136136671132853,
#  0.00024106862246439534,
#  0.00022642970557105194,
#  0.0002092877155090837,
#  0.00021691849544481676,
#  0.00023160627674014263,
#  0.00021225679617924533,
#  0.00020128739529864627,
#  0.00021573422376100924,
#  0.00021430308149146245,
#  0.00019261683180198463,
#  0.00018722302771257784,
#  0.00018952726614741258,
#  0.0001916425464616022,
#  0.00018611626662857236,
#  0.00018080416279341028,
#  0.0001670521536649263,
#  0.00016952447725849642,
#  0.000163695023021898,
#  0.00017911542903791287,
#  0.00017790393921696782,
#  0.00016640688566689252,
#  0.0001616765927700713,
#  0.0001578470364348733,
#  0.000156140857494442,
#  0.00015977255560317786,
#  0.0001581615032926493,
#  0.0001615876863646631,
#  0.00014929227824821942,
#  0.0001632591871750164,
#  0.00015512075221429554]

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 102), quantum_loss_test)
plt.ylabel('Test Loss')
plt.xlabel('Epoch')
plt.show()
# Out:
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\807507582.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 102), quantum_loss_test)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 101), quantum_acc_test)
plt.ylabel('Test Accuracy')
plt.xlabel('Epoch')
plt.show()
# Out:
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\1820591017.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 101), quantum_acc_test)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 101), quantum_loss_train)
plt.ylabel('Test Loss')
plt.xlabel('Epoch')
plt.show()
# Out:
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\596135756.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 101), quantum_loss_train)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 101), quantum_acc_train)
plt.ylabel('Test Accuracy')
plt.xlabel('Epoch')
plt.show()
# Out:
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\1240068121.py:2: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 101), quantum_acc_train)

# %%
##Comparison between classical and quantum
plt.figure(figsize=(12, 7))
plt.plot(range(1, 3272), df_out_Q["Cierre"], label = "Real")
plt.plot(range(1, 3272), df_out["Model forecast"], label = "LSTM")
plt.plot(range(1, 3272), df_out_Q["Model forecast"], label = "QLSTM")
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.vlines(size, ymin = 0, ymax = 60000, label = "Test set start", linestyles = "dashed")
plt.legend()
plt.show()
# Out:
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\149644250.py:3: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 3272), df_out_Q["Cierre"], label = "Real")
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\149644250.py:4: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 3272), df_out["Model forecast"], label = "LSTM")
# C:\Users\uriel\AppData\Local\Temp\ipykernel_11024\149644250.py:5: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   plt.plot(range(1, 3272), df_out_Q["Model forecast"], label = "QLSTM")
